# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://flights.ctrip.com/international/search/domestic"
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.39 (KHTML, like Gecko) Chrome/72.0.3626.109 Safari/537.39'
}
res = requests.get(url,headers=headers)
soup = BeautifulSoup(res.content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-cn" xmlns="http://www.w3.org/1999/html">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="webkit" name="renderer"/>
# <meta content="携程机票官网提供飞机票查询,机票预订和特价机票查询,打折机票查询服务。携程同时动态提供航班查询,时刻表查询,机票查询时刻表票价,实时起降查询,以东方航空,中国南方航空,中国国航,深圳航空,厦门航空,海南航空,四川航空,春秋航空官方网站特价机票查询,是您网上订机票的首选。" name="description"/>
# <meta content="机票,机票预订,机票查询,飞机票,飞机票查询,特价机票,打折机票,订机票,网上订票,机票价格查询,特价机票查询,飞机票价查询" name="keywords"/>
# <title>【携程机票】飞机票查询,机票预订,机票价格查询,打折特价机票</title>
# <link charset="UTF-8" href="//webresource.c-ctrip.com/ResFltIntlOnline/R20201021/styles/index.css?v=R20201021" rel="stylesheet" type="text/css"/>
# <script>
# ...

# %%
soup.title.string
# Out:
# '【携程机票】飞机票查询,机票预订,机票价格查询,打折特价机票'

# %%
soup.find_all(attrs={"method": "post"})
# Out:
# []

# %%
import json

url2 = 'https://flights.ctrip.com/itinerary/api/12808/products'
datas = json.dumps({"flightWay":"Oneway","classType":"ALL","hasChild":False,"hasBaby":False,"searchIndex":1,"date":"2020-10-26","airportParams":[{"dcity":"BJS","acity":"WUH","dcityname":"北京","acityname":"武汉","date":"2020-10-25","dcityid":1,"acityid":477}],"token":"dbee5e51946a383f48d2a7448f6d5a5f"})

headers2 = {'Content-Type': 'application/json'}

res2 = requests.post(url2,data=datas,headers=headers2)
res2.text
# Out:
# '{"data":{"version":"V2","error":null,"routeList":[{"routeType":"Flight","nearRouteCity":null,"legs":[{"flightId":"171740155","legType":"Flight","flight":{"id":"171740155","flightNumber":"MU2456","sharedFlightNumber":"","sharedFlightName":null,"airlineCode":"MU","airlineName":"东方航空","craftTypeCode":"73E","craftKind":"M","craftTypeName":"波音737","craftTypeKindDisplayName":"中型","specialCraft":false,"departureAirportInfo":{"cityTlc":"BJS","cityName":"北京","airportTlc":"PKX","airportName":"大兴国际机场","terminal":{"id":2942,"name":"","shortName":""}},"arrivalAirportInfo":{"cityTlc":"WUH","cityName":"武汉","airportTlc":"WUH","airportName":"天河国际机场","terminal":{"id":1509,"name":"T3","shortName":"T3"}},"departureDate":"2020-10-25 21:05:00","delayedTime":null,"arrivalDate":"2020-10-25 23:15:00","comfort":null,"punctualityRate":"100%","mealType":"None","mealFlag":true,"oilFee":0,"tax":50,"durationDays":0,"stopTimes":0,"stopInfo":null},"cabins":[{"id":"933120512","transitCabinIds":null,"combinedCabinIds
# ...

# %%
soup2 = BeautifulSoup(res2.content,'html.parser')
soup2
# Out:
# {"status":0,"data":{"error":{"code":"1004","msg":"查询异常，请稍后再试"},"loginState":0}}

# %%
# Out:
# <Response [200]>
